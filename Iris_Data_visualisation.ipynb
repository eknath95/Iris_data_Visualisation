# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
iris=pd.read_csv(r'C:\Users\eknath.LAPTOP-BK5NENJ9\Downloads\4th,5th\4th,5th\IRIS DATASET _ ADVANCE VISUALIZATION _ EDA 2\Iris.csv')

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris.drop('Id',axis=1,inplace=True)

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plt.scatter('Species','SepalLengthCm',data=iris)

# %%
iris['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
sns.countplot('Species',data=iris)
plt.show()

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.jointplot('SepalLengthCm','SepalWidthCm',data=iris)
plt.show()

# %%
sns.jointplot('SepalLengthCm','SepalWidthCm',data=iris,kind='reg')
plt.show()

# %%
sns.jointplot('SepalLengthCm','SepalWidthCm',data=iris,kind='hex')
plt.show()

# %%
g=sns.FacetGrid(data=iris,hue='Species')
g=g.map(plt.scatter,'SepalLengthCm','SepalWidthCm')
g=g.add_legend()

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
f,ax=plt.subplots(figsize=(8,6))
ax=sns.boxplot('Species','PetalLengthCm',data=iris,order=['Iris-virginica','Iris-versicolor','Iris-setosa'],linewidth=2.5,orient='v',dodge=False)

# %%
iris.boxplot(by='Species',figsize=(8,6))
# Out:
# array([[<AxesSubplot:title={'center':'PetalLengthCm'}, xlabel='[Species]'>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}, xlabel='[Species]'>],
#        [<AxesSubplot:title={'center':'SepalLengthCm'}, xlabel='[Species]'>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}, xlabel='[Species]'>]],
#       dtype=object)

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.stripplot(x='Species',y='SepalLengthCm',data=iris,jitter=True,edgecolor='gray',size=8,palette='winter',orient='v')
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.boxplot(x='Species',y='SepalLengthCm',data=iris)
sns.stripplot(x='Species',y='SepalLengthCm',data=iris,jitter=True,edgecolor='gray')
plt.show()

# %%
ax= sns.boxplot(x="Species", y="PetalLengthCm", data=iris)
ax= sns.stripplot(x="Species", y="PetalLengthCm", data=iris, jitter=True, edgecolor="gray")

boxtwo = ax.artists[2]
boxtwo.set_facecolor('yellow')
boxtwo.set_edgecolor('black')
boxthree=ax.artists[1]
boxthree.set_facecolor('red')
boxthree.set_edgecolor('black')
boxthree=ax.artists[0]
boxthree.set_facecolor('green')
boxthree.set_edgecolor('black')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [40], in <cell line: 4>()
#       1 ax= sns.boxplot(x="Species", y="PetalLengthCm", data=iris)
#       2 ax= sns.stripplot(x="Species", y="PetalLengthCm", data=iris, jitter=True, edgecolor="gray")
# ----> 4 boxtwo = ax.artists[2]
#       5 boxtwo.set_facecolor('yellow')
#       6 boxtwo.set_edgecolor('black')
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:1368, in _AxesBase.ArtistList.__getitem__(self, key)
#    1367 def __getitem__(self, key):
# -> 1368     return [artist
#    1369             for artist in self._axes._children
#    1370             if self._type_check(artist)][key]
#
# IndexError: list index out of range

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.violinplot(x='Species',y='SepalLengthCm',data=iris)
plt.show()

# %%
f,ax=plt.subplots(2,2,figsize=(15,10))
sns.violinplot(x='Species',y='PetalLengthCm',data=iris,ax=ax[0,0])
sns.violinplot(x='Species',y='PetalWidthCm',data=iris,ax=ax[0,1])
sns.violinplot(x='Species',y='SepalLengthCm',data=iris,ax=ax[1,0])
sns.violinplot(x='Species',y='SepalWidthCm',data=iris,ax=ax[1,1])
plt.show()

# %%
sns.pairplot(data=iris,kind='scatter')
plt.show()

# %%
sns.pairplot(iris,hue='Species')
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.heatmap(iris.corr(),annot=True,cmap='cubehelix',linewidths=1,linecolor='k',square=True,mask=False,vmin=-1,vmax=1,cbar_kws={"orientation": "vertical"},cbar=True)
# Out:
# <AxesSubplot:>

# %%
#f,ax=plt.subplots(figsize=(8,6))
iris.hist(edgecolor='black',linewidth=1.2)
fig=plt.gcf()
fig.set_size_inches(12,6)
plt.show()

# %%
sns.set_style('darkgrid')
f,ax=plt.subplots(figsize=(8,6))
sns.swarmplot(x='Species',y='PetalLengthCm',data=iris)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.violinplot(x='Species',y='PetalLengthCm',data=iris,inner=None)
sns.swarmplot(x='Species',y='PetalLengthCm',data=iris,color='white',edgecolor='black')
plt.show()

# %%
sns.lmplot(x='PetalLengthCm',y='PetalWidthCm',data=iris)
plt.show()

# %%
g=sns.FacetGrid(iris,hue="Species",size=6)
g=g.map(sns.kdeplot,'PetalLengthCm')
g=g.add_legend()

# %%
sns.factorplot('Species','SepalLengthCm',data=iris)
plt.show()

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.boxenplot(x='Species',y='SepalLengthCm',data=iris)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalLengthCm'>

# %%
sub=iris[iris['Species']=='Iris-setosa']
sns.kdeplot(data=sub,x='SepalLengthCm',y='SepalWidthCm',color="red", shade=True, shade_lowest=False)
plt.title('Iris-setosa')
plt.xlabel('Sepal Length Cm')
plt.ylabel('Sepal Width Cm')
# Out:
# Text(0, 0.5, 'Sepal Width Cm')

# %%
sns.set_style('darkgrid')
f,ax=plt.subplots(2,2,figsize=(10,8))
sns.boxplot(x="Species",y='PetalLengthCm',data=iris,ax=ax[0,0])
sns.violinplot(x='Species',y='PetalLengthCm',data=iris,ax=ax[0,1])
sns.stripplot(x='Species',y='SepalLengthCm',data=iris,jitter=True,edgecolor='gray',size=8,palette='winter',orient='v',ax=ax[1,0])
ax[1,1].hist(iris.PetalLengthCm,bins=100)
plt.show()
